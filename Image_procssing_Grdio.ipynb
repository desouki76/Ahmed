# %% [markdown]
# <a href="https://colab.research.google.com/github/desouki76/Ahmed/blob/main/Image_procssing_Grdio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gradio

# %%
import gradio as gr
#demo gr,inter fun ياخد اسم و رجعه

def greet (name):
  return f"hello" +name+"!"
demo=gr.Interface(fn=great,inputs="text",outputs="text")
demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://1ff3a63bbdc7d206ac.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://1ff3a63bbdc7d206ac.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def process (name, age, like_ai):
  return f"Name: {name}, Age: {age}, Likes AI: {like_ai}"

  demo=gr.interface (fn=process, inputs =[gr.Text(), gr.number(), grCheackbox(label=" Do u like AI")], outputs="text")
  demo.lunch()

# %% [markdown]
# Grdi can deal with image

# %%
from PIL import Image
import numpy as np
import gradio as gr
#ارفغ صورع و حولها رمادى و اسود
def to_grayscale(img):
  return img.convert("L")
demo=gr.Interface(fn=to_grayscale, inputs=gr.Image(type="pil"), outputs="image")
demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://402196d47f255ba0ad.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://402196d47f255ba0ad.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
