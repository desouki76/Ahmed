# %% [markdown]
# <a href="https://colab.research.google.com/github/desouki76/Ahmed/blob/main/House_Price_regression_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Build up Price predection model for House priceing Using pytorch technology

# %% [markdown]
# #Lib.

# %%
import numpy as np
import pandas as pd
import sklearn.model_selection
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score, mean_squared_error, mean_absolute_error

# %% [markdown]
# #Load Data

# %%
df=pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv')
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# cheack Data size

# %%
df.shape
# Out:
# (506, 14)

# %% [markdown]
# ممكن يصل لمالين

# %%
# to cheack if there are data is null

df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# write code remove null if passes specafic ratio

# %% [markdown]
# # معالجة Missing Data

# %%
null_ratio = df.isnull().sum() / len(df)
# drop coulmm if the mnull data ration > 30%
df = df.drop(columns = null_ratio[null_ratio > 0.3].index, axis=1)
#df=df.drop(null_ratio[null_ratio > 0.3].index, axis=1)

# %% [markdown]
# if i have missing data from kind object or string i will fill with imunit and if i have data missing object i will fill it with mode

# %%
#string missing will be filled by mode and string will be filled with Median
# لف على مكل ال العواميد و شيك على توعيه داتا
for col in df.columns:
  if df[col].dtype == 'object':
    df[col] = df[col].fillna(df[col].mode()[0])
  else:
    df[col] = df[col].fillna(df[col].median()) #No [0] as i have only one
#

# %%
#if i have data string by iget dummeies
df=pd.get_dummies(df)

# %% [markdown]
# قسم الداتا

# %%
x=df.drop('medv',axis=1).values #i deal with colums so i sue axis = 1
#if i use without .valuse then it will be "series" and data fream but if i use .values at end then i use numpy
y=df['medv'].values.reshape(-1,1)
#.reshape(-1,1) at end of the prvouis command which transfer to one array reagrdress of the numbner of rows (-1 put them in one colmns

# %%
#i will cheackl as this data is array 1 DImension and i need to transfer it to array coulmn
y.shape
y # will get the data   one arry add coulm or one arry as row
# Out:
# array([[24. ],
#        [21.6],
#        [34.7],
#        [33.4],
#        [36.2],
#        [28.7],
#        [22.9],
#        [27.1],
#        [16.5],
#        [18.9],
#        [15. ],
#        [18.9],
#        [21.7],
#        [20.4],
#        [18.2],
#        [19.9],
#        [23.1],
#        [17.5],
#        [20.2],
#        [18.2],
#        [13.6],
#        [19.6],
#        [15.2],
#        [14.5],
#        [15.6],
#        [13.9],
#        [16.6],
#        [14.8],
#        [18.4],
#        [21. ],
#        [12.7],
#        [14.5],
#        [13.2],
#        [13.1],
#        [13.5],
#        [18.9],
#        [20. ],
#        [21. ],
#        [24.7],
#        [30.8],
#        [34.9],
#        [26.6],
#        [25.3],
#        [24.7],
#        [21.2],
#        [19.3],
#        [20. ],
#        [16.6],
#        [14.4],
#        [19.4],
#        [19.7],
#        [20.5],
#        [25. ],
#        [23.4],
#        [18.9],
#        [35.4],
#        [24.7],
#        [31.6],
# ...

# %%
y.shape
# Out:
# (506, 1)

# %% [markdown]
# split Data and scale

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# Pytotch  regression classfication (توقع)
# diffrence will be
# 1- numnber of neurons in last layer
# 2- Loss fucation
# metric calsssficaiton
# actaivation fucaiton
#
# step1 convert data to tensot

# %% [markdown]
# # Step 1 convert data to tensor

# %%
x_train = torch.tensor(x_train, dtype=torch.float32)
x_test = torch.tensor(x_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)
#convert from nump to tesnort

# %% [markdown]
# *[italicized text](https://)*

# %% [markdown]
# # Step 1: Build model defintion

# %%
#Build calss
# regression model
# 1- Loss fucaiton -
# 2- Metric MSE
# 3- Number of nerounes in last layer will be vlaue
# 4- Loss fucaiton for hidden layer
# 5- Loss fucaiton of output layer cal
class HusPrcRegModel(nn.Module):
  def __init__(self, input_dim, output_dim):
    super(HusPrcRegModel, self).__init__()
    nn.Sequential(
        nn.Linear(input_dim, 128),     #define 1st Layer number of Nerouns in 1st layer
        nn.ReLU(),                      #define activation function
        nn.Linear(128, 64),  # define 2nd layer with input  128 which is number of Nof the prvouis layer then i define the number of N for this layer
        nn.ReLU(),
        nn.Linear(64, 32),
        nn.ReLU(),
    )
